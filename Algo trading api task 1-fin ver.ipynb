# %%
from binance.client import Client

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
api_key = "llero1JwWS5HXldpnXdlOnbGAVcXJW6saLPHsoIjocMqyLk7HfSyCa1DAgglFA13"
api_secret = "JhixiXfU5EuA8ojRQwmbOkdoJjTR2909eZaAQWpPI441C08ZBLzgDNRDz8m9VSHp"
tran_id = 1

# %%
client = Client(api_key, api_secret, {"verify": False, "timeout": 120}, testnet=True)

# %%
client.get_account()
# Out:
# C:\Users\tejas\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'testnet.binance.vision'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': False,
#  'canDeposit': False,
#  'updateTime': 1646312220794,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BNB',
#    'free': '1000.00000000',
#    'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.02300000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '100.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '500.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '500000.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '8992.55041206', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '50000.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
def getmindata(symbol, interval, lookback):
    frame = pd.DataFrame(client.get_historical_klines(symbol, interval, lookback + 'min ago UTC'))
    frame = frame.iloc[:,:6]
    frame.columns = ['Time', 'Open','High', 'Low', 'Close', 'Volume']
    frame = frame.set_index('Time')
    frame.index = pd.to_datetime(frame.index, unit='ms')
    frame = frame.astype(float)
    return frame

# %%
getmindata('BTCUSDT', '1m', '30')
# Out:
# C:\Users\tejas\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'testnet.binance.vision'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\tejas\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'testnet.binance.vision'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                          Open      High       Low     Close    Volume
# Time
# 2022-03-04 13:59:00  41264.18  41308.40  41254.16  41308.40  3.653069
# 2022-03-04 14:00:00  41314.66  41346.02  41298.04  41335.37  3.565089
# 2022-03-04 14:01:00  41332.67  41357.00  41323.14  41331.38  3.672194
# 2022-03-04 14:02:00  41329.00  41351.66  41325.70  41349.09  1.884498
# 2022-03-04 14:03:00  41345.41  41350.99  41316.76  41333.78  2.990856
# 2022-03-04 14:04:00  41333.78  41381.89  41333.77  41368.30  3.628024
# 2022-03-04 14:05:00  41365.25  41379.12  41312.01  41313.14  4.098968
# 2022-03-04 14:06:00  41313.44  41317.77  41234.33  41258.14  2.124553
# 2022-03-04 14:07:00  41258.13  41258.13  41178.03  41191.82  2.335480
# 2022-03-04 14:08:00  41193.89  41196.86  41150.00  41150.00  2.878645
# 2022-03-04 14:09:00  41150.00  41205.81  41142.41  41170.20  3.587252
# 2022-03-04 14:10:00  41170.20  41225.85  41163.46  41191.78  2.962579
# 2022-03-04 14:11:00  41191.74  41193.46  41160.20  41190.63  2.506944
# 2022-03-04 14:12:00  41187.77  41201.20  41177.09  41189.71  3.399615
# 2022-03-04 14:13:00  41189.71  41216.27  41177.91  41197.43  3.227585
# 2022-03-04 14:14:00  41197.43  41197.43  41172.97  41180.43  3.036789
# 2022-03-04 14:15:00  41172.90  41175.59  41084.88  41086.01  2.816941
# 2022-03-04 14:16:00  41084.88  41127.43  40886.41  41035.53  3.746898
# 2022-03-04 14:17:00  41035.53  41132.42  40944.55  41132.42  4.727707
# 2022-03-04 14:18:00  41132.42  41316.95  41132.42  41241.19  3.844931
# 2022-03-04 14:19:00  41239.08  41250.51  41110.90  41110.90  2.813932
# 2022-03-04 14:20:00  41109.71  41211.43  41035.09  41206.90  5.085193
# 2022-03-04 14:21:00  41206.90  41299.23  41192.16  41299.23  4.013446
# 2022-03-04 14:22:00  41286.77  41373.03  41239.02  41373.03  3.560550
# 2022-03-04 14:23:00  41373.03  41373.31  41308.07  41349.74  3.003382
# 2022-03-04 14:24:00  41348.26  41363.85  41314.15  41314.15  3.126658
# 2022-03-04 14:25:00  41312.72  41349.85  41281.74  41349.85  3.863425
# 2022-03-04 14:26:00  41349.85  41350.32  41262.71  41262.71  3.878026
# 2022-03-04 14:27:00  41261.14  41333.54  41260.95  41303.07  3.042744
# 2022-03-04 14:28:00  41305.01  41336.50  41301.40  41336.50  2.070767

# %%
def strat(symbol, qty, entried=False):
    while True:
        global tran_id
        df = getmindata(symbol, '1m', '30')
        cumret = (df.Open.pct_change() +1).cumprod() - 1
        if not entried:
            order = client.create_order(symbol=symbol ,side='BUY', type = 'MARKET', quantity = qty, newClientOrderId = "ALGOINTERN_OID"+str(tran_id))
            print(order)
            entried = True
#             print(1)
        if entried:
            while True:
#                 print(2)
                df = getmindata(symbol, '1m', '0.3')
                sincebuy = df.loc[df.index > pd.to_datetime(order['transactTime'], unit = "ms")]
                if len(sincebuy) > 0:
                    sincebuyret = (sincebuy.Open.pct_change() +1).cumprod() - 1
                    if sincebuyret[-1] < 0.005:
#                         print(3)
                        order = client.create_order(symbol=symbol ,side='SELL', type = 'MARKET', quantity = qty, newClientOrderId = "ALGOINTERN_SL_OID"+str(tran_id))
                        print(order)
                        tran_id = tran_id+1
                        entried = False
                        break
        break

# %%
strat('BTCUSDT', 0.001)
# Out:
# {'symbol': 'BTCUSDT', 'orderId': 1257663, 'orderListId': -1, 'clientOrderId': 'ALGOINTERN_OID9', 'transactTime': 1646405043362, 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'cummulativeQuoteQty': '41.20386000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '41203.86000000', 'qty': '0.00100000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 368929}]}
# {'symbol': 'BTCUSDT', 'orderId': 1258205, 'orderListId': -1, 'clientOrderId': 'ALGOINTERN_SL_OID9', 'transactTime': 1646405161441, 'price': '0.00000000', 'origQty': '0.00100000', 'executedQty': '0.00100000', 'cummulativeQuoteQty': '41.06169000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '41061.69000000', 'qty': '0.00100000', 'commission': '0.00000000', 'commissionAsset': 'USDT', 'tradeId': 369187}]}
